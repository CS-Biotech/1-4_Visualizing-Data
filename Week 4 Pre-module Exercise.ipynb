# %% [markdown]
# # Week 4: Visualizing Data 📊
# ## Pre-module
#
# One of the most powerful skills in data science is visualization. Data scientists and researchers rely not only on numbers, but plots and diagrams to guide their analysis. Visualization also helps us demonstrate our findings to a wider audience, which is one of our primary goals; if the results cannot be understood by others easily, all our work would be for naught. This week's modules will focus on tools for visualizing data.
#
# In this module you will learn:
# 1. How to generate histograms using ```hist()```
#
# First, run the cell below to load the dataset.

# %%
import pandas as pd
df = pd.read_csv('hf_data_tut.csv')
df

# %% [markdown]
# ## Histograms
#
# We learned some valuable information from descriptive statistics in the previous week, but it is difficult to get a sense of the distribution of data just by looking at the percentiles generated by by the DataFrame function ```describe()```. We can leverage visualization functions to generate histograms of the data so we can better understand the distribution in one snapshot.
#
# Pandas DataFrames have a convenient function for this purpose, called ```hist()```. This function will generate a histogram for each column in your DataFrame with the default style settings. It has many optional parameters that allow you to specify the number of buckets, the columns you want (if not all), the size and labels of the plots, and more.
#
#
# | Function | Input parameters | Output | Syntax |
# | --- | --- | --- | --- |
# | hist() | n/a (see documentation for optional parameters) | A histogram for each column in the DataFrame. | df.hist() |

# %%
df.hist(figsize=(8,10))

# %% [markdown]
# **Q1.** By looking at the histograms (do not do any calculation), which continuous features appear to have a normal distribution?
#
# <span style="background-color: #FFD700">**Write your answer here.**</span>
#
# Answer:
#
# **Q2.** Are any of the binary features imbalanced?
#
# <span style="background-color: #FFD700">**Write your answer here.**</span>
#
# Answer:
#
# **Q3.** Is the outcome class (DEATH_EVENT) imbalanced? If so, why might this be a disadvantage for our analysis if we apply statistical models to predict death in heart failure patients?
#
# <span style="background-color: #FFD700">**Write your answer here.**</span>
#
# Answer:

# %% [markdown]
# **GQ: Using your knowledge of subsetting dataframes, please complete the code box below to make a histogram plot of column age. Only include rows of individuals with diabetes.**

# %%
# Write your code here
...

# %% [markdown]
# ## Conclusion
#
# Great! Now you know how to generate histograms for your DataFrame using the pandas library. But what about other plots like scatter plots, box plots, and more? You will unlock these plotting functionalities in tutorial using pandas and other libraries. These skills are in high demand in graduate school and beyond!
#
# In this module you have seen:
# 1. How to generate histograms using ```hist()```

# %% [markdown]
# ## Further Reading
# * Explore different graphs you can generate in Python, using various libraries: https://python-graph-gallery.com/
