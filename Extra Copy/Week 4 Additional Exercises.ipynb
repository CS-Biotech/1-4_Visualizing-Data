# %% [markdown]
# # Week 4: Visualizing Data 📊
# # Additional Exercises
#
# This week's additional exercises will focus on enhancing our plots by incorporating more advanced visual features. These improvements aim to increase the interpretative value of our visualizations. By the conclusion of these exercises, our objective is to produce plots that are not just tools for data organization, but also of a quality suitable for publication.
#
# To get a better grasp of the visualization packages we are using, it is always beneficial to read the documentation for them. Here are the links to the documentation for seaborn and pandas plot.
#
# **Seaborn**: https://seaborn.pydata.org/tutorial.html
# **Pandas Plot**: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html
#
# In the code below, we are once again generating the heatmap from the main module.

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('hf_data_tut.csv')


#TODO: Add additional customization below

# generate the heatmap
heatmap = sns.heatmap(df.corr(), annot=True, cmap='Reds')
# Resize the plot for better viewing
heatmap.figure.set_figwidth(15)
heatmap.figure.set_figheight(10)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Heart Failure Data')

# %% [markdown]
# This plot effectively serves our analytical needs, as we are familiar with the context of the data and the specific questions it helps us address. Yet, for others lacking this background, the significance of the heatmap might not be immediately clear. To bridge this gap, we'll enhance the diagram with additional informative elements, ensuring it conveys the necessary context and insights more clearly to all viewers. **Starting off, in the code cell above, lets add a title.** You can do so with the ```set_title()``` function.

# %% [markdown]
# Now without altering the title and keeping the default parameters, our title may look a bit small and insignificant. It would be nice to see if we can change the characteristics of the title and adjust its font size to be bigger. To do so, you will have to change the argument ```fontdict``` in the function. As the name suggests, this parameter takes a dictionary of characteristics to the font that will be used for the title. We are specifically interested in ```fontsize```. Therefore, to accomplish this, **please set the ```'fontsize'``` key in the ```fontdict``` parameter to the value 20**.

# %% [markdown]
# As a final adjustment to the title of the heatmap, we would like to move the title a bit farther away from the heatmap itself. To do this you will have to **adjust the ```pad``` parameter in ```set_title()```; set it to 15**.

# %% [markdown]
# Moving on to other things, let's say that we would like to change the colours displayed in the heatmap. As indicators of heart disease is usually a important concern, it may be appropriate to stress the criticallity of these correlations. To do so, let us change the colour scheme used for the heatmap. Instead of blue, we can use or range of reds to stress the health concerning nature of our data. To do so, **please alter the cmap parameter**.

# %% [markdown]
# Finally, let us change the font size of the correlation scores. In the original heatmap function, we went over the ```annot``` parameter with shows the values within each grid. However, if we would like to give this heatmap in a presentation, it would be beneficial to increase the font size. To do so, we can provide a similar dictionary to the one we used earlier to change the font size of our title. The key in the dictionary would be ```'size'```. **Please add the dictionary to the parameter ```annot_kws``` to the instantiation of the heatmap object to change the font size to 12.**

# %% [markdown]
# ## Conclusion
#
# Following these recent modifications, interpreting the heatmap has become considerably more straightforward. Enhancements such as increasing the font sizes, incorporating images, and altering the color scheme have collectively transformed the diagram, making it significantly easier to understand and analyze.
